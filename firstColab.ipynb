# %% [markdown]
# <a href="https://colab.research.google.com/github/Galaszkiewicz/Node.js_challenge_dzien_1/blob/master/firstColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('o Fuck!!!')
# Out:
# o Fuck!!!

# %%
a = 209
if a > 33:
  print('acha')
else: print('Nope')
# Out:
# acha
